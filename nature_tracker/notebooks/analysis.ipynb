# %% [markdown]
# # Nature Tracker — full pipeline (notebook)
#
# Use the `pipeline/` modules from the project root (`nature_tracker/`). Stages 2–6 will be added after Stage 1 is verified.
#
# **Stage 1 (example):**
#
# ```python
# from pathlib import Path
# from pipeline.extract_frames import extract_frames
#
# extract_frames(Path("/path/to/video.mp4"))
# ```
